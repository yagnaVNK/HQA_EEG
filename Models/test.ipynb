# %%
from VQAE_EEG import VQAE_EEG
from torchsummary import summary
import torch
from nnspt.segmentation.unet import Unet

model = Unet(in_channels=32, out_channels=6, encoder='timm-efficientnet-b1')
#model = VQAE_EEG()
model = model.to("cuda")

model.decoder
# Out:
# Decoder(
#   (blocks): ModuleList(
#     (0): DecoderBlock(
#       (attention1): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(432, 27, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(27, 432, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(432, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#       (conv1): Sequential(
#         (0): Conv1d(432, 320, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv1d(320, 320, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(320, 20, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(20, 320, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(320, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#     )
#     (1): DecoderBlock(
#       (attention1): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(360, 22, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(22, 360, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(360, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#       (conv1): Sequential(
#         (0): Conv1d(360, 112, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv1d(112, 112, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(112, 7, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(7, 112, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(112, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#     )
#     (2): DecoderBlock(
#       (attention1): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(136, 8, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(8, 136, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(136, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#       (conv1): Sequential(
#         (0): Conv1d(136, 40, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(40, 2, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(2, 40, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(40, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#     )
#     (3): DecoderBlock(
#       (attention1): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(72, 4, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(4, 72, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(72, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#       (conv1): Sequential(
#         (0): Conv1d(72, 24, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv1d(24, 24, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(24, 1, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(1, 24, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(24, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#     )
#     (4): DecoderBlock(
#       (attention1): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(24, 1, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(1, 24, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(24, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#       (conv1): Sequential(
#         (0): Conv1d(24, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): SpatialChannelSqueezeExcitationBlock(
#         (cSE): Sequential(
#           (0): AdaptiveAvgPool1d(output_size=1)
#           (1): Conv1d(32, 2, kernel_size=(1,), stride=(1,))
#           (2): ReLU(inplace=True)
#           (3): Conv1d(2, 32, kernel_size=(1,), stride=(1,))
#           (4): Sigmoid()
#         )
#         (sSE): Sequential(
#           (0): Conv1d(32, 1, kernel_size=(1,), stride=(1,))
#           (1): Sigmoid()
#         )
#       )
#     )
#   )
# )
